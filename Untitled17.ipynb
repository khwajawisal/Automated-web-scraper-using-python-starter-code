# %%
import bs4
import requests
from urllib.request import urlopen as ureq
from bs4 import BeautifulSoup as soup

# %%
myurl='https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0&otracker1=AS_Query_TrendingAutoSuggest_1_0&as-pos=1&as-type=TRENDING&as-backfill=on'

# %%
uclient=ureq(myurl)

# %%
page_html=uclient.read

# %%
uclient.close()

# %%
r = requests.get(myurl)
page_soup = soup(r.content)
# Out:
# C:\Users\khwaja wisal\Anaconda3\envs\tensorflow\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\khwaja wisal\Anaconda3\envs\tensorflow\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
page_soup.h1

# %%
page_soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.59cbcf.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
containers = page_soup.findAll("div",{"class":"_3O0U0u"})

# %%
containers[0]
# Out:
# <div class="_3O0U0u"><div data-id="MOBFDXZ376XRTZXH" style="width:100%"><div class="_1UoZlX"><a class="_31qSD5" href="/redmi-note-7-pro-neptune-blue-64-gb/p/itmfegkx8nbcze6t?pid=MOBFDXZ376XRTZXH&amp;srno=s_1_1&amp;otracker=AS_Query_TrendingAutoSuggest_1_0&amp;otracker1=AS_Query_TrendingAutoSuggest_1_0&amp;lid=LSTMOBFDXZ376XRTZXHWRK63O&amp;fm=organic&amp;iid=63891e15-b61e-4de8-aa9b-8cb43b18fe55.MOBFDXZ376XRTZXH.SEARCH&amp;qH=eb4af0bf07c16429" rel="noopener noreferrer" target="_blank"><div class="_3RW86r">ON OFFER</div><div class="_3SQWE6"><div class="_1OCn9C"><div><div class="_3BTv9X" style="height:200px;width:200px"><img alt="Redmi Note 7 Pro (Neptune Blue, 64 GB)" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/></div></div><div class="_3aV9Tq"><span class="rIHMVr">Coming Soon</span></div></div><div class="_2lesQu"><div class="_1O_CiZ"><span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox"/><
# ...

# %%
len(containers)
b=[]
b=containers[0].div.a['href']
b='https://www.flipkart.com'+b
b
# Out:
# 'https://www.flipkart.com/redmi-note-7-pro-neptune-blue-64-gb/p/itmfegkx8nbcze6t?pid=MOBFDXZ376XRTZXH&srno=s_1_1&otracker=AS_Query_TrendingAutoSuggest_1_0&otracker1=AS_Query_TrendingAutoSuggest_1_0&lid=LSTMOBFDXZ376XRTZXHWRK63O&fm=organic&iid=63891e15-b61e-4de8-aa9b-8cb43b18fe55.MOBFDXZ376XRTZXH.SEARCH&qH=eb4af0bf07c16429'

# %%
url2=ureq(b)
page_html2=url2.read
url2.close()

# %%
r1 = requests.get(b)
page_soup2 = soup(r1.content)
# Out:
# C:\Users\khwaja wisal\Anaconda3\envs\tensorflow\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\khwaja wisal\Anaconda3\envs\tensorflow\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
page_soup2
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.59cbcf.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
container2=page_soup2.findAll("li",{"class":"_3YhLQA"})
container3=page_soup2.findAll("td",{"class":"_3-wDH3 col col-3-12"})
len(container2)
# Out:
# 63

# %%
feature=[]
for i in range(0,63):
    
    feature[i]=container2[i].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-114-ac612a895396> in <module>()
#       2 for i in range(0,63):
#       3
# ----> 4     feature[i]=container2[i].text
#
# IndexError: list assignment index out of range

# %%
r34=[]
r34.append(container2[0].text)
r34.append(container2[1].text)
r34.append(container2[2].text)
r34.append(container2[3].text)
r34.append(container2[4].text)
r34.append(container2[5].text)
r34.append(container2[6].text)
r34.append(container2[7].text)
r34.append(container2[8].text)
r34.append(container2[9].text)
r34.append(container2[10].text)
r34.append(container2[11].text)
r34.append(container2[12].text)
r34.append(container2[13].text)
r34.append(container2[14].text)
r34.append(container2[15].text)
r34.append(container2[16].text)
r34.append(container2[17].text)
r34.append(container2[18].text)
r34.append(container2[19].text)
r34.append(container2[20].text)
r34.append(container2[21].text)
r34.append(container2[22].text)
r34.append(container2[23].text)
r34.append(container2[24].text)
r34.append(container2[25].text)
r34.append(container2[26].text)
r34.append(container2[27].text)
r34.append(container2[28].text)
r34.append(container2[29].text)
r34.append(container2[30].text)
r34.append(container2[31].text)
r34.append(container2[32].text)
r34.append(container2[33].text)
r34.append(container2[34].text)
r34.append(container2[35].text)
r34.append(container2[36].text)
r34.append(container2[37].text)
r34.append(container2[38].text)
r34.append(container2[39].text)
r34.append(container2[40].text)
r34.append(container2[41].text)
r34.append(container2[42].text)
r34.append(container2[43].text)
r34.append(container2[44].text)
r34.append(container2[45].text)
r34.append(container2[46].text)
r34.append(container2[47].text)
r34.append(container2[48].text)
r34.append(container2[49].text)
r34.append(container2[50].text)
r34.append(container2[51].text)
r34.append(container2[52].text)
r34.append(container2[53].text)
r34.append(container2[54].text)
r34.append(container2[55].text)
r34.append(container2[56].text)
r34.append(container2[57].text)
r34.append(container2[58].text)
r34.append(container2[59].text)
r34.append(container2[60].text)
r34.append(container2[61].text)
r34.append(container2[62].text)

# %%
r34
# Out:
# ['Handset, SIM Ejector Tool, Soft Case, Manual, Adapter, Cable',
#  'MZB7464IN',
#  'Redmi Note 7 Pro',
#  'Neptune Blue',
#  'Smartphones',
#  'Dual Sim',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Speaker - Single (Bottom Opening), Microphones - 2 (For Noise Cancellation), Smart PA',
#  'India SAR 1g limit: 1.6W/Kg, Head SAR: 0.962W/Kg (0mm Separation), Body SAR Value: 0.838W/Kg (15mm Separation)',
#  '16.0 cm (6.3 inch)',
#  '2340 x 1080 pixels',
#  'FHD+',
#  'Adreno 612',
#  'IPS (In-cell), RD',
#  'Contrast Ratio - 1500:1, NTSC Ratio - 81.41%, 2.5D Glass (In-front), Corning Gorilla Glass 5 (Front and Back), Dot Notch Display',
#  'Android Pie 9.0',
#  'Qualcomm Snapdragon 675',
#  'Octa Core',
#  '2.0 GHz',
#  '1.7 GHz',
#  'GSM - B2, B3, B5, B8, WCDMA - B1, B2, B5, B8, LTE TDD - B40, B41, LTE FDD - B1, B3, B5, B8, CA - 1C (Only DLCA), 3C, 40C, 41C',
#  '64 GB',
#  '4 GB',
#  '256 GB',
#  'microSD',
#  'Hybrid Slot',
#  'Yes',
#  '48MP + 5MP',
# ...

# %%
r35=[]
r35.append(container3[0].text)
r35.append(container3[1].text)
r35.append(container3[2].text)
r35.append(container3[3].text)
r35.append(container3[4].text)
r35.append(container3[5].text)
r35.append(container3[6].text)
r35.append(container3[7].text)
r35.append(container3[8].text)
r35.append(container3[9].text)
r35.append(container3[10].text)
r35.append(container3[11].text)
r35.append(container3[12].text)
r35.append(container3[13].text)
r35.append(container3[14].text)
r35.append(container3[15].text)
r35.append(container3[16].text)
r35.append(container3[17].text)
r35.append(container3[18].text)
r35.append(container3[19].text)
r35.append(container3[20].text)
r35.append(container3[21].text)
r35.append(container3[22].text)
r35.append(container3[23].text)
r35.append(container3[24].text)
r35.append(container3[25].text)
r35.append(container3[26].text)
r35.append(container3[27].text)
r35.append(container3[28].text)
r35.append(container3[29].text)
r35.append(container3[30].text)
r35.append(container3[31].text)
r35.append(container3[32].text)
r35.append(container3[33].text)
r35.append(container3[34].text)
r35.append(container3[35].text)
r35.append(container3[36].text)
r35.append(container3[37].text)
r35.append(container3[38].text)
r35.append(container3[39].text)
r35.append(container3[40].text)
r35.append(container3[41].text)
r35.append(container3[42].text)
r35.append(container3[43].text)
r35.append(container3[44].text)
r35.append(container3[45].text)
r35.append(container3[46].text)
r35.append(container3[47].text)
r35.append(container3[48].text)
r35.append(container3[49].text)
r35.append(container3[50].text)
r35.append(container3[51].text)
r35.append(container3[52].text)
r35.append(container3[53].text)
r35.append(container3[54].text)
r35.append(container3[55].text)
r35.append(container3[56].text)
r35.append(container3[57].text)
r35.append(container3[58].text)
r35.append(container3[59].text)
r35.append(container3[60].text)
r35.append(container3[61].text)
r35.append(container3[62].text)

# %%
r35
# Out:
# ['In The Box',
#  'Model Number',
#  'Model Name',
#  'Color',
#  'Browse Type',
#  'SIM Type',
#  'Hybrid Sim Slot',
#  'Touchscreen',
#  'OTG Compatible',
#  'Quick Charging',
#  'Sound Enhancements',
#  'SAR Value',
#  'Display Size',
#  'Resolution',
#  'Resolution Type',
#  'GPU',
#  'Display Type',
#  'Other Display Features',
#  'Operating System',
#  'Processor Type',
#  'Processor Core',
#  'Primary Clock Speed',
#  'Secondary Clock Speed',
#  'Operating Frequency',
#  'Internal Storage',
#  'RAM',
#  'Expandable Storage',
#  'Supported Memory Card Type',
#  'Memory Card Slot Type',
#  'Primary Camera Available',
#  'Primary Camera',
#  'Primary Camera Features',
#  'Secondary Camera Available',
#  'Secondary Camera',
#  'Secondary Camera Features',
#  'Flash',
#  'HD Recording',
#  'Full HD Recording',
#  'Video Recording',
#  'Dual Camera Lens',
#  'Network Type',
#  'Supported Networks',
#  'Internet Connectivity',
#  'Bluetooth Support',
#  'Bluetooth Version',
# ...

# %%
rnew=dict(zip(r35,r34))

# %%
rnew
# Out:
# {'Audio Jack': '3.5mm',
#  'Battery Capacity': '4000 mAh',
#  'Bluetooth Support': 'Yes',
#  'Bluetooth Version': 'v5.0',
#  'Browse Type': 'Smartphones',
#  'Color': 'Neptune Blue',
#  'Depth': '8.1 mm',
#  'Display Size': '16.0 cm (6.3 inch)',
#  'Display Type': 'IPS (In-cell), RD',
#  'Dual Camera Lens': 'Primary Camera',
#  'Expandable Storage': '256 GB',
#  'Flash': 'Single Tone Dual LED Flash',
#  'Full HD Recording': 'Yes',
#  'GPS Support': 'Yes',
#  'GPS Type': 'A-GPS, GLONASS, BeiDou',
#  'GPU': 'Adreno 612',
#  'Graphics PPI': '409 PPI',
#  'HD Recording': 'Yes',
#  'Height': '159.21 mm',
#  'Hybrid Sim Slot': 'Yes',
#  'In The Box': 'Handset, SIM Ejector Tool, Soft Case, Manual, Adapter, Cable',
#  'Internal Storage': '64 GB',
#  'Internet Connectivity': '4G, 3G, Wi-Fi',
#  'Map Support': 'Google Maps',
#  'Memory Card Slot Type': 'Hybrid Slot',
#  'Model Name': 'Redmi Note 7 Pro',
#  'Model Number': 'MZB7464IN',
#  'Network Type': '4G VOLTE, 3G, 2G',
# ...

# %%
wanted_keys=['Model Number','Model Name','Processor type','GPU','Hybrid Sim Slot','Processor Core','Primary Clock Speed','Secondary Clock Speed','Graphics PPI','Display Size','Operating System','Resolution','Internal Storage','External Storage','RAM','Primary Camera','Secondary Camera','Battery Capacity','Weight','Depth']
new_dict = {k: rnew[k] for k in set(wanted_keys) & set(rnew.keys())}

# %%
new_dict
# Out:
# {'Battery Capacity': '4000 mAh',
#  'Depth': '8.1 mm',
#  'Display Size': '16.0 cm (6.3 inch)',
#  'GPU': 'Adreno 612',
#  'Graphics PPI': '409 PPI',
#  'Hybrid Sim Slot': 'Yes',
#  'Internal Storage': '64 GB',
#  'Model Name': 'Redmi Note 7 Pro',
#  'Model Number': 'MZB7464IN',
#  'Operating System': 'Android Pie 9.0',
#  'Primary Camera': '48MP + 5MP',
#  'Primary Clock Speed': '2.0 GHz',
#  'Processor Core': 'Octa Core',
#  'RAM': '4 GB',
#  'Resolution': '2340 x 1080 pixels',
#  'Secondary Camera': '13MP',
#  'Secondary Clock Speed': '1.7 GHz',
#  'Weight': '186 g'}

# %%
nl=new_dict.values
import pandas as pd
# Out:
# <function dict.values>

# %%
finaldf=pd.DataFrame(new_dict, index=[0])

# %%
finaldf
# Out:
#   Battery Capacity   Depth        Display Size         GPU Graphics PPI  \
# 0         4000 mAh  8.1 mm  16.0 cm (6.3 inch)  Adreno 612      409 PPI
#
#   Hybrid Sim Slot Internal Storage        Model Name Model Number  \
# 0             Yes            64 GB  Redmi Note 7 Pro    MZB7464IN
#
#   Operating System Primary Camera Primary Clock Speed Processor Core   RAM  \
# 0  Android Pie 9.0     48MP + 5MP             2.0 GHz      Octa Core  4 GB
#
#            Resolution Secondary Camera Secondary Clock Speed Weight
# 0  2340 x 1080 pixels             13MP               1.7 GHz  186 g
